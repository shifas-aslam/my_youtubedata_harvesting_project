# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyDJmK_6vf--oQQpRavSQ2XNyaX8xyI8KkE'
###channel_id = 'UC2J_VKrAzOEJuQvFFtj3KUw'
channel_ids = ['UC2J_VKrAzOEJuQvFFtj3KUw', #csk
               'UC4FUjHHzr753fv9vQ4mE32g', #tamil cricket news
               'UCXsJyNCjFthPLQ9U5KI-Frg', #kickflix
               'UCNMg6XDhRZI2QzL4pWOvP_w', #volleyball world
               'UCtInrnU3QbWqFGsdKT1GZtg', #fiba-the baseketball
              ]
               
youtube=build('youtube','v3',developerKey=api_key)

# %% [markdown]
# ##Functional to get Channel Statistics

# %%
def get_channel_stats(youtube,channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(channel_name=response['items'][i]['snippet'] ['title'],
                    subscribers=response['items'][i]['statistics']['subscriberCount'],
                    views=response['items'][i]['statistics']['viewCount'],
                    Total_videos=response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])

        all_data.append(data)
        
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#                     channel_name subscribers       views Total_videos  \
# 0             Tamil Cricket News      230000    71748705          918
# 1                       KickFlix     1150000   485915421           54
# 2               Volleyball World     2610000  1043495304         7445
# 3            Chennai Super Kings     3150000   624130183         1099
# 4  FIBA - The Basketball Channel     2290000   871087286        27853
#
#                 playlist_id
# 0  UU4FUjHHzr753fv9vQ4mE32g
# 1  UUXsJyNCjFthPLQ9U5KI-Frg
# 2  UUNMg6XDhRZI2QzL4pWOvP_w
# 3  UU2J_VKrAzOEJuQvFFtj3KUw
# 4  UUtInrnU3QbWqFGsdKT1GZtg

# %%
channel_data['subscribers'] = pd.to_numeric(channel_data['subscribers'])
channel_data['views'] = pd.to_numeric(channel_data['views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# channel_name    object
# subscribers      int64
# views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
sns.set(rc={'figure.figsize':(14,12)})
ax = sns.barplot(x='channel_name',y='subscribers',data=channel_data)

# %%
ax = sns.barplot(x='channel_name',y='views',data=channel_data)

# %% [markdown]
# ## Function to get video ids

# %%
channel_data
# Out:
#                     channel_name  subscribers       views  Total_videos  \
# 0             Tamil Cricket News       230000    71748705           918
# 1                       KickFlix      1150000   485915421            54
# 2               Volleyball World      2610000  1043495304          7445
# 3            Chennai Super Kings      3150000   624130183          1099
# 4  FIBA - The Basketball Channel      2290000   871087286         27853
#
#                 playlist_id
# 0  UU4FUjHHzr753fv9vQ4mE32g
# 1  UUXsJyNCjFthPLQ9U5KI-Frg
# 2  UUNMg6XDhRZI2QzL4pWOvP_w
# 3  UU2J_VKrAzOEJuQvFFtj3KUw
# 4  UUtInrnU3QbWqFGsdKT1GZtg

# %%
playlist_id=channel_data.loc[channel_data['channel_name']=='Volleyball World','playlist_id'].iloc[0]

# %%
def get_video_ids(youtube,playlist_id):
    request=youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=50)
    response=request.execute()
    
    video_ids=[]
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages=False
        else:
            request=youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)
            response=request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
                
            next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
video_ids=get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['pHYSeMDDdvo',
#  'c3ZbEvDRs3M',
#  'YQlZjg46sZQ',
#  'eFMEDRg74Gc',
#  '2NriMHGZJnw',
#  '8CpWT32XJAU',
#  'jeF6WsYZLRw',
#  'pHDIRwvR4fA',
#  '3l_epTb-2jY',
#  'bBMfnVvC9j4',
#  'uh4fBHCh_TI',
#  'd3tYXFSQ_6Q',
#  'r3xHh_l5_A8',
#  'rrbA7yEEfBo',
#  'EXKYkDKU73M',
#  'GkDnzz7TLwU',
#  'agRWpeS-hyo',
#  'RP6XfjHFR4I',
#  'WNfh5UiiLGE',
#  'iZFiMXUrJJ0',
#  'PLBT4ef1bBI',
#  'fEVkZugVmus',
#  'kddRro4xDyQ',
#  '2rYQjECN_OA',
#  'y8YrZ33J9E4',
#  '99NkNSyq2SI',
#  'HRv83mq8oI0',
#  'u9G6-mqA3Xs',
#  'OPwrM4kAcvk',
#  '475irB9Clh8',
#  'gDcwmzRjvBw',
#  'FThS0z1v9nE',
#  'AnGfQNsRBOg',
#  'NFfT8G8vwsU',
#  'Q5qBDNDZTLY',
#  'Q6n9YgAVjpU',
#  'IHh54ZG_e9k',
#  'av7Jx9SVYk8',
#  '_utHwXgS2qc',
#  'PXegE8eyIIQ',
#  'xWAUsuYR6as',
#  '8u_M6QNPNrg',
#  'GxkNzSCP_wI',
#  '23Wjeoj9isg',
#  'Y9LFA8ponTA',
#  'rDwX41T484w',
#  'wLQV87y7aZY',
#  'haHPoOOMvb8',
#  'pZYbGpFspVA',
#  'lZf1ayEN_9E',
#  '1_xYDdSGzVM',
#  'oBqisKy-PYw',
#  '2NY1Jqsw_tY',
#  'G3AXzePMJYI',
#  'SgaLxRaXuxM',
#  'X1GJm9Ri7kg',
#  'btibEd6RtUs',
#  'YP7rKrg9i2M',
#  'N8_pAed_P1k',
#  'XQMffBFLnP8',
#  '4DJ5E5YGsj4',
#  'GBj3dPmUrtw',
#  'K1qXJD6pKCM',
#  'yyYvVR5KH0s',
#  'l71R-dnyx4o',
#  'ZzxLP0v3L5s',
#  'AT0lsuvS05s',
#  'ztfW1rDnKtE',
#  'eyhfun6Mpbo',
#  '5QLfOUAv5Bw',
#  'pRt9PskGRpI',
#  'mIytXN6J6KE',
#  'ThhMqsmyDss',
#  '3v7KOu6pXik',
#  'Ma57KOC6M_g',
#  '15vB6dDMX5o',
#  'etn4WYJRHVU',
#  'NVjXO2iqPJE',
#  'sj22hzJc8T4',
#  'jZFkcmCOdcQ',
#  'gZMtmmK4P9w',
#  'BmY-2yVvksM',
#  'wNy56HjD1jM',
#  'JyQcjK01kmM',
#  't95QCmHkEx4',
#  'HHJQNpZvotU',
#  'HFD8X_HfZbs',
#  '5Q66VokbVNU',
#  'rkqrq1lwpmM',
#  '86_ahcjEFA4',
#  'PJDGctiQRaU',
#  'BwK50c3wBl4',
#  'f6vl5OG8r9A',
#  'G8z7-3Uo5sM',
#  'Zuqrmq7OtT4',
#  'Uoi0EfhZsZc',
#  'LaH4aaqRI64',
#  'UqjpXoZOHp4',
#  '0-WxSevElh4',
#  'vxmr9BVchmM',
#  'wKBOefLkuNA',
#  'I3U0fsXe7Gc',
#  'n4hBimDsieU',
#  'qGrgJSlkXb0',
#  'eFqZIQoCA7I',
#  'qJghjddFb3s',
#  'UH2SU_OfN4o',
#  'S6CfbmwU9m4',
#  '0IkeKySHmkA',
#  'Lhw9f2v03N8',
#  'V7kW56DVgeM',
#  'UeRcXt7s3gw',
#  'mbO9-4d2Sbs',
#  '038ADPY4T1M',
#  'C_oREaOFp1M',
#  'ov87B2lcn1I',
#  '7_TDrY939NA',
#  'rImXO2bXX-g',
#  'zgmJO052xhE',
#  '7YIZRlHPUeQ',
#  '8iU02-ujTnk',
#  'pMESBFWrfe0',
#  'uu7Xno9-aTc',
#  '_4UMhmd9bTc',
#  'lqHz55uTB-0',
#  'u-cvrKVV9cA',
#  'fMKE0Nq8R7o',
#  'DYBMSm8Ma5c',
#  'F9uvXnLmv58',
#  'V-njdRnsWnA',
#  'iSi4uYaQOQ8',
#  '1qLPxjwR8Co',
#  'EMaDaTsHsZk',
#  'c7NNjRSqgak',
#  'cw7GBgUSN3Q',
#  'VaUFG3SFhuk',
#  '9DDsxjkRK1g',
#  'aejYLVsaQlk',
#  'A2ReNiaBwg4',
#  'YhpDeGhf6Rw',
#  '8uIqEUaQFTA',
#  '8bU_pgPgM_s',
#  'wwb9fSkWQBc',
#  'FCKyGhv_Ne4',
#  'PCsRqZba3ds',
#  'xDi8BXuTXdY',
#  'c9jODQS_NV8',
#  'vAfB-hFoK-U',
#  'sNWHKO-B6lk',
#  'bhyXTwupZ5E',
#  'KvjQAZh4a0U',
#  '3hdWqDWcM5c',
#  '0pW8y4exu_E',
#  'GbhahyLpuIA',
#  'Jfj5pcKb024',
#  'WRyXO-PydRw',
#  'TzQtHaoCDms',
#  'PaoIMtd31Ps',
#  '0EGZXo0BM30',
#  'MdrPaIQVYkE',
#  'O5uv7ZAzAkc',
#  'x7OzXWg_xgc',
#  'SF0it872VwM',
#  'Lwsqi4w1ri4',
#  'X8RZ2-ySW94',
#  'fgy4YYgYi-k',
#  'rRrnD1a0Vss',
#  'YIvtxIx6wO8',
#  'bvofXzCmjw8',
#  'xh7tFCRyPY8',
#  'LDWHmORNdLs',
#  'C-C9DKw5dS8',
#  '1DpgTwGMMY4',
#  'pTfMsSKgp_c',
#  'ffsYb7e5cG0',
#  'QMNATUbpE9s',
#  'B7AbzL1bVdM',
#  'ZwBcPhz96ds',
#  'QsvDbzeBe8E',
#  'hi6urSqobg8',
#  'wX-HG2gOYyU',
#  'UQ3aHrwKqYA',
#  '-tJBC4WUyYI',
#  'r2JWTPrEc1k',
#  'jkt6AQMKhxE',
#  'nMuB850skJE',
#  'Ul2yNF4GvlQ',
#  'Gu5yPyFzuhY',
#  'Rp249HNGtUk',
#  '9dTA-pu7-1o',
#  'mD6xYr5RdQU',
#  'Qxb0OHlyPBI',
#  'PMwMDfPFKiQ',
#  '--Y47uVUf9Q',
#  'KyUShBZAJuc',
#  'GTjt5SGvXKc',
#  'Rr0DdYtr558',
#  'rLZ4qAumquk',
#  'bDwLZVbErzQ',
#  'nP6vrbMg8o0',
#  'L2ozoHRpCBc',
#  'f03RSoEgjsg',
#  '6_L20YuwZe4',
#  '58JuzUVEdT8',
#  '9DQEdcY7vjc',
#  '7aQXqjMBshk',
#  '4iO602n5P3w',
#  'cYPkGr7JXl0',
#  'D3sBInLLf9U',
#  'kacaXLioEfs',
#  '59wY2ra39R8',
#  'xWeHSOKhVoY',
#  'uzj0X_pn04w',
#  'DW7XQz38oVw',
#  'We0HEyZa_wE',
#  'jC42gPt4toE',
#  'jOqjl4oDc4U',
#  'UcPy-zB-ego',
#  'JjEAGdrIVvw',
#  'fBysEz334RQ',
#  'rDKHsdGifVU',
#  'lB9fbp_Vr2s',
#  'BrO7m--696E',
#  'Eiv5KvFbUnY',
#  '5Wu05kPJMK8',
#  'HTGrUzN2vB4',
#  'nvWpp7t7tRg',
#  'vCXMMoGM2Os',
#  'tRuOuv8DceI',
#  'DvhC6c_TYhw',
#  'z8dh6WdQzO0',
#  'YAHH3x3GUBw',
#  'DOO0rfIhfJI',
#  'tq2AbI6oqZc',
#  's8AccmC7kkw',
#  '_nla3NafO8c',
#  'eTSzKIU3p8A',
#  '6SMzOa3AL2M',
#  'QmZqjaW5I_Y',
#  'sNLuYsJdCCk',
#  'Hh3QHi8gnLE',
#  'CX2xjLUn7c8',
#  'gNwFzoj_gfM',
#  'W47qsyiJGIw',
#  'CNpnn_dCH58',
#  '81wu1n3brX4',
#  'rAsypYnBjvc',
#  'gFcjT5ttvDM',
#  'W8_3zGUb0rg',
#  '2IsItyEBxN0',
#  'IwlC5XYV2rc',
#  'cvbuMxPfjcw',
#  'Dv5NxUp238w',
#  'WtRrPJItBRo',
#  'ZSWZIV2OfYQ',
#  'UO8iFqd13Zg',
#  'RzESy3CN7Fg',
#  '6syvZKmBIQ4',
#  'eRtYrpQMSM8',
#  '828URYHeQ2g',
#  'fqfD4PJkpys',
#  'f7o7nhE96mM',
#  'wCQaUL1Ktgg',
#  'rX3ydD-fu5I',
#  'B1WQMSp9SFI',
#  'pi_n0NxE8kQ',
#  'tIy-eHh06jc',
#  'y76RaAP9jgU',
#  'RS7KF_GP7oA',
#  '9X5ovb-6F4k',
#  'Ixtt5CptzV8',
#  'p0m9TB3CoVg',
#  'TQ8s2ASJDU0',
#  'ebHgv6EUuMs',
#  '1nubYRBCb3I',
#  'fZHAeG3vpms',
#  '7_DKIWoqySU',
#  '9GZmZHyoTL0',
#  'h5SPfUfkFC4',
#  'm5tPBijPFig',
#  '-qhMiDaxx38',
#  'kKZWDIGk-Ro',
#  'WN6GM7C72HA',
#  'i-oxdTUN7a0',
#  'TI75vEigl7U',
#  'cN-MRV9MeoI',
#  'jYXt82NProU',
#  'FUDz_HmVtKI',
#  'EgTGmg09qJo',
#  'tAbQmDz77i8',
#  'Yj0tTyLl9Js',
#  '29aNK1yz5qQ',
#  'yY9sGMIl5Uw',
#  '0QJ4Cc_yA7w',
#  'WwF36kP17-c',
#  'tsmkdGGQRJ8',
#  'a4bSBRbrcPA',
#  'MrLBl9EFDVs',
#  'oWumIwm7t0c',
#  '2p8EaYRRI0g',
#  'tzCEVLfDfh0',
#  'k3nzXbay1Q0',
#  'EuQBgblh-8M',
#  'cGTzbmXFEOc',
#  't3MFjt2U9SY',
#  '01OAgyoS4X0',
#  'L4L4P6QVpfE',
#  'lJKlfIMRzKw',
#  'gVO1OMjGxuM',
#  '3r_Werb2ekg',
#  'csLFjtQMMH8',
#  'fMkw0WtKyKg',
#  'y4FAHPLyXA0',
#  'mBxawWpTosk',
#  'x7vA2oZUcFA',
#  'IvVSkV6b5oU',
#  'ZImaCYmjcSM',
#  'Mtc4b47TgC4',
#  '-Qrc8prEuWQ',
#  'W1uR5Afj9ds',
#  'c9h4yv6kWK8',
#  'vSNDekGGB1I',
#  'G9QzCIEn66I',
#  'aruZ_vmQ7Eg',
#  'hQoWkiP5nX4',
#  'cDkpCd4mAPM',
#  'lJyQAYQwjbM',
#  'zfhpsRYBoHc',
#  'M7gggcAy6nk',
#  'IdEXaXtfsSU',
#  '8Q1N8JrPaRI',
#  '1nPoTpC9AMQ',
#  '1LxwplKf2oI',
#  '08GILg_kPOs',
#  'GJWrTOaMh5Q',
#  'waz6rFYs364',
#  '662Dwxkxw1Q',
#  'sRU-nmpw2Qo',
#  'qBEDnlcgorc',
#  '-KgcWTIrzFw',
#  'i_U1xkbM47A',
#  'nqzBU6iwMZw',
#  'Mrn5y5zJeyY',
#  'a5RGpcwhAbU',
#  'ngFeCxus9OU',
#  'gpxdTq1Km5k',
#  'ZQTUnxjhn40',
#  'ZQU1bicQtiM',
#  'FhFtjCzfFE0',
#  '3LlHYHqhH5k',
#  '-8xDidKmx1Y',
#  'hXPj4fK1mHg',
#  'ALcusn2vkEE',
#  'Z_WzAALAtKo',
#  'U-IGmtAv6qs',
#  'I0tzztiJmaE',
#  'qW5F_bo5lsc',
#  'wjIx6AzVEaw',
#  'Juji8diQV-o',
#  'kylSVkY2Tg4',
#  'UN2wkrcgINU',
#  'SI05WZTNBHE',
#  '_OYNiAa12io',
#  'fb0shMPPyl0',
#  'JyB38PZPtTI',
#  '_RQ67VO1Ei4',
#  'vOJ-KxhaX-M',
#  'KEXWCr3w434',
#  '-aTd-jAPmh0',
#  'C6FXv0Pp810',
#  'EeTpkMi2aE4',
#  'Kem0nHWAx5Y',
#  'P39_r0UJh10',
#  'xUK_-dnek_U',
#  '0PyX37KO8rQ',
#  'HdKMw060YnY',
#  'gJ5nCiARjDk',
#  '4oSAFbGYNtM',
#  '58JpPZzOiNs',
#  'negOrOwCgTU',
#  'J2AwL7d9xZ4',
#  'RzDjQdm6Mr4',
#  'nGYEup25k84',
#  '1JySHJKcM2c',
#  'GA9d1I9bYxc',
#  'u64RQg9yMac',
#  'SgY0AovMy3E',
#  'gFs0qXx10Cs',
#  '4QYBwptZZw8',
#  '_2I9px2Ijf0',
#  'fq7EHsigo1g',
#  'DrufepZrm-4',
#  '510IseV1q9o',
#  'JQGDi4QJpBo',
#  'kBsK4-H-PM8',
#  '68yQZbFVE44',
#  'UyXNwKoY5Mw',
#  'KxcLZ9ZiHF4',
#  '7uFLbpStE5k',
#  'DAT8bhj0h7k',
#  'jIxkUBk1QYs',
#  'a9K41z9UkY0',
#  'W77zzcLopoc',
#  'A-MOhyyTJSY',
#  'KfE6Ml6IfjE',
#  'R33bjLzJakM',
#  'V-B410nlmgc',
#  'UiiWk0M9Q1c',
#  'cla272vi3IE',
#  'kKwglaUFCe8',
#  'I8TpgHxtJa4',
#  's4pUAsKEl2w',
#  'EdpZWQ-_wy4',
#  'odIb3GA3aC8',
#  'RTzJ0L3cuPs',
#  'dDZguxAIpDM',
#  '6x36kvWhkYs',
#  'rFQbhQQi_h8',
#  '802CA_E1E4U',
#  'XSxzxuM25JU',
#  'IjEzqZzjD1o',
#  'H3I6wZnFc5I',
#  '650t2Kf_hAs',
#  'pBERlts8AnQ',
#  'sxJkQ_b4aqk',
#  'tvI_KHSY1OI',
#  'd5WsdpF6F88',
#  'XJh9NEKpgPs',
#  'Hbvq2wY0Cu8',
#  '3hzNS8YLNWg',
#  '9UC5Gjet0Xs',
#  'Iy8HmOAQQVs',
#  'Tk3bPpbXt8o',
#  'Z3uUfBA1KUE',
#  'GK0Yctt1WXs',
#  'jQmgPAazMeA',
#  'N0xmC8aH29g',
#  'XL5i4v_h1zQ',
#  'EqJoOf5f94A',
#  'eW583-lh1oM',
#  'oKXZ4Wg2fVg',
#  'i7el2M67ndY',
#  '6IFPJkhg_nI',
#  'of3TsMG6xyw',
#  '4Ti_1x5g8F0',
#  'xKZQZvJNFXE',
#  'Vi9PDR3Bi2o',
#  'YLLjN_6C8YA',
#  'qv1es9rIEW4',
#  'i8H9NftLZ5Q',
#  'c0EjGi9Gd-0',
#  '2d-Ds0GbDfk',
#  'VUkNyDEImc0',
#  'TBsUfWz8uX8',
#  '_G3h-p6d4fs',
#  '9dtorAWu_hk',
#  'tBHy9x3sx3g',
#  '7whjj7pAgmE',
#  'hIK9NcWSwNA',
#  'FpRkKqpMX4Y',
#  'J0vK3PSkvp0',
#  'OKxW-TDu3K8',
#  '8h4rO_lUHEc',
#  '69gFwn-8ijc',
#  'FZCRJBVPRok',
#  '_Y0U4D01saE',
#  'Cg4dQq6gSPA',
#  'Fs7rA3bjRHE',
#  '7wbXmvRTW4g',
#  'UHmOXGro7QA',
#  '21yjIJLg98M',
#  'KftxAxfWg2U',
#  'U4hqePU-qvg',
#  'y53_5f4gC7g',
#  'Zel1IGBM7sg',
#  '-w0z0cRt2Qk',
#  '9E0xjYoxOIU',
#  'jQMyKXLvF_k',
#  'Mj_5Dkr9460',
#  'Zv7_fkozPUY',
#  'GOtcOqhA4S0',
#  '85lHNuC3BRY',
#  'a_bg03WFlY0',
#  'l8ItTV4dn8k',
#  'a-zAsr8Kn44',
#  'wImMZfDbNYE',
#  'K8-qUpjbzwg',
#  'B5Q3ewepXog',
#  'Ad2oyRT4-wI',
#  'GiTBjWwyH1M',
#  'Et-INsiLvfM',
#  'AZSrEhwVvBw',
#  'QDYJoe62pV8',
#  'JfmFhk9bzEE',
#  'vVJ8ZX5kVWE',
#  '2MFVPTgNIWw',
#  'Hm1tkoNWeBw',
#  '_5_kxbjjn3U',
#  'IruiIhYyZxc',
#  'kkIOyu7uWWM',
#  'DS4iVV8_cp4',
#  '58SRD9W34Bc',
#  'FILtux2s3zU',
#  'OJQUE3I4TLo',
#  'zeD8gpFEmMg',
#  'q9cQvjtzO2Y',
#  'HJxwJHIwil4',
#  'TG1-4-YK-U8',
#  '7w_7o9V-7X8',
#  'ICLBumdISy8',
#  'o24gEmY1BzU',
#  'eO3jsnjhjTg',
#  'wQNg_i7EZPE',
#  'qUcDb3enGeA',
#  'GjGjNaeebeE',
#  'ytocpFKnRZQ',
#  'EiXNIgiTZ3Q',
#  'KUQsHt1ee3U',
#  'ZXm2lNBVlOw',
#  '3zLeKWxQjm4',
#  'feirPF1By0o',
#  '8AuPEFOmZ_o',
#  'CqHtMs0ByX8',
#  'S3FOjhVllxs',
#  'L1QUD5y63jI',
#  'HlKhdCM4CdM',
#  'iYWgjAWoI5k',
#  'FmkY3p2YloE',
#  'kGsK8QPxZJU',
#  '7poscqD8eRA',
#  'EzLohhot3mI',
#  'ymO5tIxUqAg',
#  '9mM1uaKRi4I',
#  '-KrV53VB4eM',
#  'qCHZcCSlj0U',
#  '8RxMBgQctE0',
#  'dNT7ODauZ0U',
#  'yPZPafVG9Y0',
#  'CGhk7k3f8lA',
#  '6fLYx461_mE',
#  'Wbt01WcLpVE',
#  'MQGOXTr-TC4',
#  'JcEViUddlSw',
#  'yDCsLH-CAkg',
#  '_suUYOXWf_s',
#  'oSY2wL4rn8w',
#  'w_kL2inwAtA',
#  'TCAP2u_1J68',
#  'FHaNCe2HAtE',
#  'YvlmYMl6GhQ',
#  'KnFrd_zKl-k',
#  'D5x_XvP1FCk',
#  'yKJPgnZfc9s',
#  'sOuOHfppT1I',
#  'naMepL7-S2Y',
#  'vGtPvnQsn0w',
#  'NoZyshYgDL4',
#  'JK6Bh9hQTUw',
#  '5aNYaLBFeJI',
#  'yX-j1yzbR1Q',
#  'TfehHop2Pgk',
#  'ZPLl2WW-Gpw',
#  'v5W8peQ8VRI',
#  'ibaeD5PsSkw',
#  'ENtKpQDpfaE',
#  'p11vXp0r3BQ',
#  'wbzxOETJdoo',
#  '2mU8qkEDyxw',
#  'v8KMVnmgaHY',
#  'ZbYTs0gXduw',
#  'UawA7tm-dmg',
#  'Hz29jGUiINI',
#  'UNeMDj8r_2E',
#  'AD1oMgT_C0Y',
#  'BzZuQvw6fmU',
#  'eduBSaAFtC0',
#  'SRV9wlU1iuM',
#  'f9Z-AqhyNtQ',
#  'HozbnHu4imE',
#  'GvhdVW1PJCU',
#  'nGflKUI28rA',
#  'gZ7ic_-TD7k',
#  'tee6hSLKFcg',
#  'hlkYiwfq570',
#  'gTUhRgGuoOc',
#  'PW4BDXsVnkM',
#  'g2xpMFu7BTk',
#  '0OwPLk7IW1k',
#  'VXKc4QXrJHw',
#  'h-nUecloh2c',
#  '7s8lFtmQUmE',
#  'YyzF1sNVQOY',
#  'GsaCNv_Zyus',
#  'xhibfkiqlFc',
#  '82Dg1XrbTpc',
#  '0-HUQ6OppjQ',
#  'qWAXherXUN8',
#  '_DxZ-PF9-dY',
#  'ZeX098c6HOo',
#  'Cj7JbCOxw3A',
#  '7yi_BdQ7gO0',
#  'aBQ0WBtQsxo',
#  'V_g3QLRftOg',
#  'X83GsHhs1zo',
#  'Xow7bNunriY',
#  'V5wfcgGcDhc',
#  'ofEq2qC_bpc',
#  'x4BZ2LsyGZU',
#  'f2_haVUm1r4',
#  'C9KlIEK_Q10',
#  'JgsLt_u4BJw',
#  '-vC7Ne0Gk2U',
#  'GSaIDSfFazE',
#  'g_8_h-Fpfeo',
#  '4uGaFxsqA_Q',
#  'PJ975_DIjWk',
#  'UEUQvM1ZixQ',
#  'yh3N5mo8dGc',
#  'l776jUJwQq4',
#  'qKOxN9Qo4uI',
#  'sgE6Jgu-byw',
#  '1J0NC9Jcw6o',
#  '5Uf3v7lrPM4',
#  '8rD2ZXiOFPw',
#  'yggzb4pT_L4',
#  'GvLYsAmZwhQ',
#  'caPfEWFRYec',
#  '278adYetUiI',
#  'FEwtIvzShBU',
#  '1CprfU7QgCY',
#  'TcHkmQjO6xs',
#  'f9oqKoZyaFU',
#  'BZc_GhKhtVg',
#  '9PMnT8HbnLA',
#  'bw6h-iyTUJw',
#  'rCcb_St8Vic',
#  'mWhUmE-LXTY',
#  'MToo5f1QDlg',
#  'hJJUM3cCsfE',
#  'm7kMpcqpnEM',
#  '0TEzZ7WQeBI',
#  'na5cCkdeMqk',
#  'wwLeq52QUK4',
#  'vSFux0KZPxY',
#  'ktj0zeKDqQQ',
#  'Xm3Kluxe370',
#  'T-B06JM4C38',
#  'hYuYFti_utU',
#  'JPciK7aHXBA',
#  'cQ6XHJJJDSw',
#  'SqlAvMzGKBo',
#  'W7pDn7vskn4',
#  'l94JJiwDIfM',
#  'eSJaH_qaPaM',
#  'Qq6NQxcQ0Rw',
#  'Z-kQtYEejqg',
#  '_NoOqH2Lpdc',
#  '2Juu9ldZDJ0',
#  'YtdpK0SyKK4',
#  'avlvFcJILg0',
#  'dgG28Pv2uFA',
#  'xtcp7jGzjGc',
#  'dFL5tA_hCNY',
#  '6va-EZQTgiA',
#  'q6odt_joYlw',
#  'xbXuzLQ8ZBM',
#  'cj0PSSb_2Tc',
#  '2G_wO2Uv-90',
#  'X7yOalkwGYU',
#  '2zlrqOeKhW0',
#  'Pe9b5Rorua8',
#  'PgVOhpiPI9Y',
#  '-p2BaK9PWUk',
#  'ReLZqBisaQg',
#  'Uen0BZ01NjQ',
#  'GSDkPDD9y0M',
#  'U5vfaHoj33o',
#  'g-7oCgrHcPg',
#  'AjHRfYo8GxQ',
#  '1OfKdkLFie8',
#  'rNrPR3_ShYs',
#  'meiOCiGtI9M',
#  'c2pzCci1iy8',
#  'poYF8m3Cf1s',
#  'j9oUzQocRro',
#  'tpYbrfe5Gvk',
#  '8h3BpLB8KxA',
#  'UgVnhBgvZ84',
#  'nWBOXyC5tB0',
#  'hilRTd1CAxg',
#  'VIXPG0xY41A',
#  'uS5pw7tbvW8',
#  'LThfRK2DgSA',
#  'SQiqbJfs-Ak',
#  '3wSdUSk-Pp0',
#  'UxIiNzx_RGQ',
#  'xhoDPs7UJAc',
#  '590EQ5iqVW0',
#  'MyXy5bhwQGo',
#  '2o8FRgjf2Rs',
#  'uSJSO4jOiBs',
#  'df6wCpVUVyU',
#  'T4o6ZjxQod8',
#  '_962CR0jSlc',
#  'VGgaA6l7YIg',
#  'Sa7KzWs-zd4',
#  'oweE8DQYFn8',
#  '1ryRMshT-8g',
#  'XgH1ljTDdgk',
#  'Dv_T0Pgu-7M',
#  'apnKn6dR4_U',
#  'cYRlwXvtJDo',
#  'IVUVGEibwzM',
#  'r2gJegRgFgg',
#  'xH1RItKi1E4',
#  'NbpmJFS8utk',
#  'Z1iujlfPujs',
#  'ILXn3Gux-uU',
#  '8M1WdSY5G-c',
#  'il1ENy0IU74',
#  'Y20fTLh-200',
#  'mo_p5GZ63DE',
#  'uFCfTFcILJQ',
#  'IRhDWcw63Ms',
#  'n3IhZe67gy0',
#  'AxjaQrtJaVw',
#  'fxSAtwcdIIU',
#  'DXzXu7qN2hE',
#  'ii5GL8NV1hw',
#  'HEDMJeVTq28',
#  'Rp0fbP1JqF4',
#  'QLmyj66I-Wo',
#  'M3j2o8kVYMs',
#  'TDBTTZpa7Po',
#  'oSkqtn8-U0I',
#  'FmXusUan16I',
#  'Mi-r_4M_pgI',
#  'ptpKKUJNhcA',
#  '2UKy7aQwaM0',
#  'IHv36tnpPew',
#  'U9wpeWjUBRg',
#  '9uPBPJRVaHg',
#  '1FgsSQiWezQ',
#  'xbtP54G8OSk',
#  'oWNkUK7jQrQ',
#  '37MNnIcBaG0',
#  'nqMP7EqrLpk',
#  'QskdBGLuOkc',
#  'xx3vX3m3Ds4',
#  'xYtjp8h95_M',
#  '0u94r1fVC4I',
#  'Vh_mJCjO7eY',
#  'Qu42iGivp1w',
#  '_vOErYt_-iE',
#  'apl-TZ-T0Aw',
#  'EQoMKUjSOpE',
#  'IOo96K3CIwk',
#  'i8vF368wh5M',
#  'j1Rl1zBvKXA',
#  'KI8IV2YXTE0',
#  'aKnoZOrRDiQ',
#  'Kxa0O1w2a30',
#  'dgNFBalRla0',
#  'KSZEW7wPOzs',
#  'UA80Kj3MLr0',
#  'TPDtg1k2Jp0',
#  'n0IUR-iWKq0',
#  '8VfHFHpjqqw',
#  'Wl6xsv4xR0Y',
#  'WCvt5mpwXwk',
#  '8QVYJPaZJRQ',
#  'lrQVgogCbp8',
#  'cd-ZgNJYAyk',
#  'AU91F6QQaro',
#  'OiubvQZRb3w',
#  'YbnC6wno1-4',
#  'lyB5pRvuYes',
#  'ZJGM_PDkD90',
#  'bfNxr13pWtQ',
#  'rVCnKPbAsT8',
#  'OTvyCCOe6sE',
#  'VkMIXCNqOLM',
#  'SjcEy_MYwDk',
#  'WGyCGli1Wlk',
#  'G9AOBWxlHp8',
#  'i3qpLMghSSY',
#  'g4rWXoiFoE0',
#  '8cNflvd18Cs',
#  '-TL-sKiGhHE',
#  'Sj5cBaer7sA',
#  'K2v7sQpjInc',
#  'dV7sUNoIQRE',
#  'Ok3IqM7Q6Xo',
#  'q2LGfr6U92Y',
#  'Pli_UxbE_vo',
#  'PLCpx8piEY0',
#  '_Q1bAawxFaw',
#  'Wa83MQo9KUo',
#  '53L9Het7X7w',
#  '0tgDh-BMsRk',
#  'EfQvE3sdpQ0',
#  '0WDur7IWnGY',
#  'iuQTktThoxs',
#  'PQk9uFt0-vQ',
#  'JZxOOlWH52w',
#  'TXXJAmwsLQg',
#  'EIj1J7_iTeU',
#  'tq23bcOc8VM',
#  'ETRRECz1tAI',
#  'qv_9vOJDF9Y',
#  '3NwTkqBFuGY',
#  'lsmTmKm4Jsk',
#  'YDSiqi-HJOc',
#  'KLn-Euvbypk',
#  'JwUMnAhqUoU',
#  'mOqgeQoIdTc',
#  'iVzOKIf9A9A',
#  'w4odxUJWBUI',
#  '_2QtmECWHpc',
#  'FEIs3S-66Zc',
#  '8N9gPMpzOY8',
#  'akLchlEQkKY',
#  '5wIOF1zSo4o',
#  'fobwmWrCLn8',
#  '-BDBHL_HJIc',
#  '-hefMUQ8d_8',
#  'qeJhPYsJKVw',
#  'GlaDNUgBXzk',
#  '5eFgL1iCF4U',
#  'fIccV4986Bo',
#  'Uc5YQoArEp4',
#  'CGyVgWNwH1w',
#  '9uLC8wMsSx0',
#  'h1pFBWn79cA',
#  'ZKmnkjIwmaU',
#  'oa_gg2giIVg',
#  '7eyYXZAmrpU',
#  'vHIcZLqkpDc',
#  'Y_3NdpfT-A4',
#  'Meyk8h6GXnE',
#  '89ThPI_qs2Q',
#  'rNNvn5NZowU',
#  'WuzXo6Gug1s',
#  'WRvQe1l6TOE',
#  'Ha8SKXEdrn8',
#  'MWUhNDGY0hw',
#  'XT-B3PiNfLU',
#  'dg41XWsEP04',
#  '_O8KjQMeVoM',
#  'uoSAfpsNFAc',
#  '-d8VzvpDQaw',
#  'm4TPEWf_8qM',
#  'A-a8zyi1UvY',
#  '4L624-UqLeQ',
#  'EZy7Fwu1_28',
#  'jUfZzC_0PPY',
#  'ruX6X9cnspg',
#  'S_sA-5obBt8',
#  'O8evSaetjLw',
#  'yfq_LIjiKHw',
#  'e4Pdmx02K8U',
#  'as7vQRk86o4',
#  'Y8tsCAYozy8',
#  'sd2NDKpPrhg',
#  'N3Mlpp2jLXU',
#  'eQdkE0t6Ar4',
#  'KLTOJDvyMOE',
#  'YpQn6fxIx1M',
#  'YUkJO3Q2Q6o',
#  'OGvTbaYvkaw',
#  'YT9a9B-_vOg',
#  'WCcB7VRUorg',
#  'Hf1BEaenOCc',
#  'W-XEFYIzehI',
#  'vRerW_J2zEA',
#  'sok301VSXpw',
#  '-Ru7Kxj9V7I',
#  'euG5IwLCfU4',
#  'gADXz2FXJTo',
#  'CepwPW7N740',
#  '3aChT4soxs8',
#  'R78MRs8kCuQ',
#  'gXxkSvE0Zq0',
#  'oBz0_Fd5V60',
#  'vJZnhbyAehw',
#  'i5CTiXsEJRI',
#  'RYtTZQOcGOg',
#  '6SyDktU9e5M',
#  'znTlGJkEsTM',
#  'ABHDNgCO9KQ',
#  '1Q2q3VkXVes',
#  'jn9VMgYG77w',
#  'erR5PwpxRHk',
#  '_Og7xaExqSs',
#  '7XSp_MUQaZw',
#  'fSA4hgv1B_k',
#  'wkO-MdwRieY',
#  '34IV-ULrP7s',
#  '2vjRT7QBpMw',
#  '2qzEFnk25a8',
#  'InXtEF8lN4M',
#  'HZEQvtGdMGA',
#  'XLsCd0DETPM',
#  'SZkOO4RdM4s',
#  'D-urfddUOa0',
#  '_7l0QZ-watk',
#  'E8abD9jZ01c',
#  'jTBmLYIoyjU',
#  'i_eXrReswWI',
#  'ztHN7rsZYYg',
#  'tcKNbnDdNrc',
#  'tiZfCwE6TNM',
#  'w6a8W4LSHkg',
#  'EgJGBe0bBss',
#  'FplUX4n-1Gc',
#  'Ls6Dsku8lvc',
#  'MV3uvGr_ePg',
#  'VJrFWn1-z5k',
#  'MBnRTB0e8BI',
#  'TZ6JUPp2F2o',
#  'zo4b5w4RqHY',
#  'JCRGmpjHx6M',
#  'ZgyWwrufmjE',
#  'pIEjcKmNblM',
#  'EtOUvaN0OmY',
#  '8P7KIshJ5To',
#  'LOnxuPmQ6Cw',
#  'jEcE5JECNXE',
#  'luPaJwKpdnE',
#  'wV8H9bwJSfc',
#  'cLOb_GS_nJ0',
#  'KD8eIHJI_84',
#  'Z4VSfv7fgmg',
#  '_JtZgjglqBE',
#  '6gxztR2mPgE',
#  'EKOagUM24Uk',
#  'GelROr9HW6c',
#  'KAagNdagve4',
#  'QpLFsNDHXQg',
#  'TNiUt1VRA9Y',
#  's-WHGxbPMeU',
#  '1xDHRQwdikU',
#  '-r6SGDlvTz0',
#  'zHFM38tmxNg',
#  'KoOX0VTZHwM',
#  'mbYHvq8lWeI',
#  'iXvlE5w7nvg',
#  'KJQtyn54ou0',
#  'AA6X4s4P0Z8',
#  'RaWM55tWaCU',
#  'GTQ8MnGDD1c',
#  'lvBqY-ffs5w',
#  'B-5ILZas4FI',
#  'BgSQvpIREAo',
#  'LCGi55Yz-CY',
#  'GnzU_0slOvE',
#  'JPsl_UnN_IU',
#  'TtPCeu5AVzU',
#  'jPUoNfc0isY',
#  'vWsmCi0eVWM',
#  'KbXYMAQF3qA',
#  'Q_be0UYBwzw',
#  'YRL19sRLZ2g',
#  'hHITO7t2hSo',
#  'sJlOgsRxZIE',
#  've2v11CTKdk',
#  'GasYiHMWhlI',
#  'Iovu46wLCug',
#  '_WZxwxIrvtI',
#  'RmStXQl6CCY',
#  'sih7Qn0WoXw',
#  '4bOK1roLNqA',
#  'ab3znsetl4M',
#  'c_CviYgzc2c',
#  'faWHED4yYUg',
#  'lSvVloIQsTc',
#  'rE-zbDTmpiw',
#  '0Juyhq_6Wg8',
#  'E8eh1Y5GarU',
#  'J6MQuS11mEE',
#  'NKLVc5jV7jw',
#  'XH9ChjumNdw',
#  'a4-3ozWvLQM',
#  'tlUHRY6pnbc',
#  'FbjRSSkRL98',
#  'h4-SJVuSaY4',
#  'GqAAaEduCM4',
#  '0yTJSacrxbY',
#  'zPBxMJQP6Es',
#  'FD3M_vXSjYk',
#  'fcez4mqv0fw',
#  'xv0ZSngpSfY',
#  '1vs7pUv52Kc',
#  '4CisiiPkcI0',
#  '9AX6bbaZHdE',
#  'aujBwzVzxw0',
#  '2aLRYsdyo-8',
#  'U4IBoghk58I',
#  'XK5Lxt6wkuo',
#  'ZmWwaMQLYPk',
#  ...]

# %% [markdown]
# # Function to get videos

# %%
def get_video_details(youtube,video_ids):
    all_video_stats=[]
    for i in range(0, len(video_ids),50):
        request=youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50]))
    response=request.execute()
        
    for video in response['items']:
        video_stats=dict(Title = video['snippet']['title'],
                         Published_date = video['snippet']['publishedAt'],
                         views=video['statistics']['viewCount'],
                         likes=video['statistics']['likeCount'],
                         comments=video['statistics']['commentCount']
                        )
        if 'dislikesCount' in video['statistics']:
            video_stats['Dislikes']=video['statistics']['dislikesCount']
        else:
            video_stats['Dislikes']= 0
            
        all_video_stats.append(video_stats)
            
        
    return all_video_stats

# %%
video_details = get_video_details(youtube,video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date']=pd.to_datetime(video_data['Published_date']).dt.date
video_data['views'] = pd.to_numeric(video_data['views'])
video_data['likes'] = pd.to_numeric(video_data['likes'])
video_data['comments'] = pd.to_numeric(video_data['comments'])
video_data['Dislikes'] = pd.to_numeric(video_data['Dislikes'])
video_data
# Out:
#                                                 Title Published_date  views  \
# 0                              Liliane Maestini (BRA)     2011-08-12   1578
# 1                                Dariam Acevedo (PUR)     2011-08-11    883
# 2                                  Natalie Cook (AUS)     2011-08-11   2020
# 3          Luk Teck Hua and Beh Shen Thing (Malaysia)     2011-08-11   5856
# 4     Josephine Nammanda and Alice Gitta Okecho (UGA)     2011-08-10   1204
# 5                                  Miller Elwin (VAN)     2011-08-09    834
# 6                        Zara Dampney & Shauna Mullin     2011-08-08  15658
# 7                               Day 5 Murillo, Brazil     2011-07-10   2443
# 8               Finals | Press conference POL-ARG 3-0     2011-07-10   1095
# 9                                 Day 5 Dante, Brazil     2011-07-10   1854
# 10                             Poland Volleyball fans     2011-07-10   2752
# 11  Polish fans celebrate their team's achievement...     2011-07-10    708
# 12                                     Lukasz Zygadlo     2011-07-10   5103
# 13          Semifinals | Press conference RUS-POL 3-1     2011-07-10    455
# 14          Semifinals | Press conference BRA ARG 3 0     2011-07-09    789
# 15               Day 3 | Press conference POL ARG 3 2     2011-07-09    660
# 16                                       Andrea Zorzi     2011-07-09   3146
# 17               Day 3 | Press conference RUS-BRA 3-0     2011-07-08   1365
# 18                                       Andrea Zorzi     2011-07-08   1154
# 19                   Day 2 | Alexander Volkov, Russia     2011-07-07   3020
# 20               Day 2 | Press conference ARG-BUL 3-0     2011-07-07   2056
# 21               Day 2 | Press conference BRA-USA 3-1     2011-07-07    701
# 22                   Day 1 | Press conference POL-BUL     2011-07-07    963
# 23                 Day 1 | Krzysztof Ignaczak, Poland     2011-07-06   5064
# 24                        Day 1 | Michal Lasko, Italy     2011-07-06   5246
# 25                              Day 1 | Bruno, Brazil     2011-07-06   1721
# 26                           Facundo Conte, Argentina     2011-07-06  14734
# 27                                       Andrea Zorzi     2011-07-05   2974
# 28                                 Emanuel and Alison     2011-06-19   1866
# 29                              May-Treanor and Walsh     2011-06-19   2436
# 30                                            Juliana     2011-06-19   1017
# 31                              Chen Xue and Xi Zhang     2011-06-19   3226
# 32                                      Dr. Ary Graca     2011-06-19    413
# 33                  Misty May-Treanor and Kerry Walsh     2011-06-18   7206
# 34                                Juliana and Larissa     2011-06-18    866
# 35                                       Julius Brink     2011-06-17   1050
# 36                              Chen Xue and Xi Zhang     2011-06-17   6255
# 37                                        Paul Laciga     2011-06-17    946
# 38                                     Greta Cicolari     2011-06-17   1142
# 39                                       Denise Johns     2011-06-17   1008
# 40                                     Jennifer Kessy     2011-06-14   4480
# 41                                     Jason Lochhead     2011-06-14   1632
# 42                       Doris and Stefanie Schwaiger     2011-06-14   2384
# 43                                   Elodie Li Yuk Lo     2011-06-13   1513
# 44  FIVB Beach Volleyball Swatch World Championshi...     2011-06-13   1463
#
#     likes  comments  Dislikes
# 0       6         1         0
# 1       5         1         0
# 2       1         1         0
# 3      12         5         0
# 4       4         1         0
# 5       2         3         0
# 6      19         7         0
# 7       6         1         0
# 8      11         1         0
# 9       9         1         0
# 10     19         3         0
# 11      4         2         0
# 12      9         0         0
# 13      0         0         0
# 14      1         2         0
# 15      4         1         0
# 16      6         1         0
# 17      0         1         0
# 18      6         0         0
# 19     28         2         0
# 20      5         0         0
# 21      1         1         0
# 22      4         1         0
# 23     40         1         0
# 24     11         8         0
# 25     13         1         0
# 26     74         3         0
# 27      3         1         0
# 28      2         3         0
# 29      0         0         0
# 30      3         1         0
# 31      8         1         0
# 32      2         1         0
# 33     12         0         0
# 34      8         1         0
# 35      0         0         0
# 36     18         0         0
# 37      1         1         0
# 38      2         0         0
# 39      4         1         0
# 40      9         2         0
# 41      5         2         0
# 42      4         0         0
# 43      6         1         0
# 44     25         9         0

# %%
top10_video=video_data.sort_values(by='views',ascending=False).head(10)

# %%
top10_video
# Out:
#                                          Title Published_date  views  likes  \
# 6                 Zara Dampney & Shauna Mullin     2011-08-08  15658     19
# 26                    Facundo Conte, Argentina     2011-07-06  14734     74
# 33           Misty May-Treanor and Kerry Walsh     2011-06-18   7206     12
# 36                       Chen Xue and Xi Zhang     2011-06-17   6255     18
# 3   Luk Teck Hua and Beh Shen Thing (Malaysia)     2011-08-11   5856     12
# 24                 Day 1 | Michal Lasko, Italy     2011-07-06   5246     11
# 12                              Lukasz Zygadlo     2011-07-10   5103      9
# 23          Day 1 | Krzysztof Ignaczak, Poland     2011-07-06   5064     40
# 40                              Jennifer Kessy     2011-06-14   4480      9
# 31                       Chen Xue and Xi Zhang     2011-06-19   3226      8
#
#     comments  Dislikes
# 6          7         0
# 26         3         0
# 33         0         0
# 36         0         0
# 3          5         0
# 24         8         0
# 12         0         0
# 23         1         0
# 40         2         0
# 31         1         0

# %%
    sns.set(rc={'figure.figsize':(14,8)})
    ax1 = sns.barplot(x='views',y='Title', data=top10_video)

# %%
video_data
# Out:
#                                                 Title Published_date  views  \
# 0                              Liliane Maestini (BRA)     2011-08-12   1578
# 1                                Dariam Acevedo (PUR)     2011-08-11    883
# 2                                  Natalie Cook (AUS)     2011-08-11   2020
# 3          Luk Teck Hua and Beh Shen Thing (Malaysia)     2011-08-11   5856
# 4     Josephine Nammanda and Alice Gitta Okecho (UGA)     2011-08-10   1204
# 5                                  Miller Elwin (VAN)     2011-08-09    834
# 6                        Zara Dampney & Shauna Mullin     2011-08-08  15658
# 7                               Day 5 Murillo, Brazil     2011-07-10   2443
# 8               Finals | Press conference POL-ARG 3-0     2011-07-10   1095
# 9                                 Day 5 Dante, Brazil     2011-07-10   1854
# 10                             Poland Volleyball fans     2011-07-10   2752
# 11  Polish fans celebrate their team's achievement...     2011-07-10    708
# 12                                     Lukasz Zygadlo     2011-07-10   5103
# 13          Semifinals | Press conference RUS-POL 3-1     2011-07-10    455
# 14          Semifinals | Press conference BRA ARG 3 0     2011-07-09    789
# 15               Day 3 | Press conference POL ARG 3 2     2011-07-09    660
# 16                                       Andrea Zorzi     2011-07-09   3146
# 17               Day 3 | Press conference RUS-BRA 3-0     2011-07-08   1365
# 18                                       Andrea Zorzi     2011-07-08   1154
# 19                   Day 2 | Alexander Volkov, Russia     2011-07-07   3020
# 20               Day 2 | Press conference ARG-BUL 3-0     2011-07-07   2056
# 21               Day 2 | Press conference BRA-USA 3-1     2011-07-07    701
# 22                   Day 1 | Press conference POL-BUL     2011-07-07    963
# 23                 Day 1 | Krzysztof Ignaczak, Poland     2011-07-06   5064
# 24                        Day 1 | Michal Lasko, Italy     2011-07-06   5246
# 25                              Day 1 | Bruno, Brazil     2011-07-06   1721
# 26                           Facundo Conte, Argentina     2011-07-06  14734
# 27                                       Andrea Zorzi     2011-07-05   2974
# 28                                 Emanuel and Alison     2011-06-19   1866
# 29                              May-Treanor and Walsh     2011-06-19   2436
# 30                                            Juliana     2011-06-19   1017
# 31                              Chen Xue and Xi Zhang     2011-06-19   3226
# 32                                      Dr. Ary Graca     2011-06-19    413
# 33                  Misty May-Treanor and Kerry Walsh     2011-06-18   7206
# 34                                Juliana and Larissa     2011-06-18    866
# 35                                       Julius Brink     2011-06-17   1050
# 36                              Chen Xue and Xi Zhang     2011-06-17   6255
# 37                                        Paul Laciga     2011-06-17    946
# 38                                     Greta Cicolari     2011-06-17   1142
# 39                                       Denise Johns     2011-06-17   1008
# 40                                     Jennifer Kessy     2011-06-14   4480
# 41                                     Jason Lochhead     2011-06-14   1632
# 42                       Doris and Stefanie Schwaiger     2011-06-14   2384
# 43                                   Elodie Li Yuk Lo     2011-06-13   1513
# 44  FIVB Beach Volleyball Swatch World Championshi...     2011-06-13   1463
#
#     likes  comments  Dislikes
# 0       6         1         0
# 1       5         1         0
# 2       1         1         0
# 3      12         5         0
# 4       4         1         0
# 5       2         3         0
# 6      19         7         0
# 7       6         1         0
# 8      11         1         0
# 9       9         1         0
# 10     19         3         0
# 11      4         2         0
# 12      9         0         0
# 13      0         0         0
# 14      1         2         0
# 15      4         1         0
# 16      6         1         0
# 17      0         1         0
# 18      6         0         0
# 19     28         2         0
# 20      5         0         0
# 21      1         1         0
# 22      4         1         0
# 23     40         1         0
# 24     11         8         0
# 25     13         1         0
# 26     74         3         0
# 27      3         1         0
# 28      2         3         0
# 29      0         0         0
# 30      3         1         0
# 31      8         1         0
# 32      2         1         0
# 33     12         0         0
# 34      8         1         0
# 35      0         0         0
# 36     18         0         0
# 37      1         1         0
# 38      2         0         0
# 39      4         1         0
# 40      9         2         0
# 41      5         2         0
# 42      4         0         0
# 43      6         1         0
# 44     25         9         0

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                 Title Published_date  views  \
# 0                              Liliane Maestini (BRA)     2011-08-12   1578
# 1                                Dariam Acevedo (PUR)     2011-08-11    883
# 2                                  Natalie Cook (AUS)     2011-08-11   2020
# 3          Luk Teck Hua and Beh Shen Thing (Malaysia)     2011-08-11   5856
# 4     Josephine Nammanda and Alice Gitta Okecho (UGA)     2011-08-10   1204
# 5                                  Miller Elwin (VAN)     2011-08-09    834
# 6                        Zara Dampney & Shauna Mullin     2011-08-08  15658
# 7                               Day 5 Murillo, Brazil     2011-07-10   2443
# 8               Finals | Press conference POL-ARG 3-0     2011-07-10   1095
# 9                                 Day 5 Dante, Brazil     2011-07-10   1854
# 10                             Poland Volleyball fans     2011-07-10   2752
# 11  Polish fans celebrate their team's achievement...     2011-07-10    708
# 12                                     Lukasz Zygadlo     2011-07-10   5103
# 13          Semifinals | Press conference RUS-POL 3-1     2011-07-10    455
# 14          Semifinals | Press conference BRA ARG 3 0     2011-07-09    789
# 15               Day 3 | Press conference POL ARG 3 2     2011-07-09    660
# 16                                       Andrea Zorzi     2011-07-09   3146
# 17               Day 3 | Press conference RUS-BRA 3-0     2011-07-08   1365
# 18                                       Andrea Zorzi     2011-07-08   1154
# 19                   Day 2 | Alexander Volkov, Russia     2011-07-07   3020
# 20               Day 2 | Press conference ARG-BUL 3-0     2011-07-07   2056
# 21               Day 2 | Press conference BRA-USA 3-1     2011-07-07    701
# 22                   Day 1 | Press conference POL-BUL     2011-07-07    963
# 23                 Day 1 | Krzysztof Ignaczak, Poland     2011-07-06   5064
# 24                        Day 1 | Michal Lasko, Italy     2011-07-06   5246
# 25                              Day 1 | Bruno, Brazil     2011-07-06   1721
# 26                           Facundo Conte, Argentina     2011-07-06  14734
# 27                                       Andrea Zorzi     2011-07-05   2974
# 28                                 Emanuel and Alison     2011-06-19   1866
# 29                              May-Treanor and Walsh     2011-06-19   2436
# 30                                            Juliana     2011-06-19   1017
# 31                              Chen Xue and Xi Zhang     2011-06-19   3226
# 32                                      Dr. Ary Graca     2011-06-19    413
# 33                  Misty May-Treanor and Kerry Walsh     2011-06-18   7206
# 34                                Juliana and Larissa     2011-06-18    866
# 35                                       Julius Brink     2011-06-17   1050
# 36                              Chen Xue and Xi Zhang     2011-06-17   6255
# 37                                        Paul Laciga     2011-06-17    946
# 38                                     Greta Cicolari     2011-06-17   1142
# 39                                       Denise Johns     2011-06-17   1008
# 40                                     Jennifer Kessy     2011-06-14   4480
# 41                                     Jason Lochhead     2011-06-14   1632
# 42                       Doris and Stefanie Schwaiger     2011-06-14   2384
# 43                                   Elodie Li Yuk Lo     2011-06-13   1513
# 44  FIVB Beach Volleyball Swatch World Championshi...     2011-06-13   1463
#
#     likes  comments  Dislikes Month
# 0       6         1         0   Aug
# 1       5         1         0   Aug
# 2       1         1         0   Aug
# 3      12         5         0   Aug
# 4       4         1         0   Aug
# 5       2         3         0   Aug
# 6      19         7         0   Aug
# 7       6         1         0   Jul
# 8      11         1         0   Jul
# 9       9         1         0   Jul
# 10     19         3         0   Jul
# 11      4         2         0   Jul
# 12      9         0         0   Jul
# 13      0         0         0   Jul
# 14      1         2         0   Jul
# 15      4         1         0   Jul
# 16      6         1         0   Jul
# 17      0         1         0   Jul
# 18      6         0         0   Jul
# 19     28         2         0   Jul
# 20      5         0         0   Jul
# 21      1         1         0   Jul
# 22      4         1         0   Jul
# 23     40         1         0   Jul
# 24     11         8         0   Jul
# 25     13         1         0   Jul
# 26     74         3         0   Jul
# 27      3         1         0   Jul
# 28      2         3         0   Jun
# 29      0         0         0   Jun
# 30      3         1         0   Jun
# 31      8         1         0   Jun
# 32      2         1         0   Jun
# 33     12         0         0   Jun
# 34      8         1         0   Jun
# 35      0         0         0   Jun
# 36     18         0         0   Jun
# 37      1         1         0   Jun
# 38      2         0         0   Jun
# 39      4         1         0   Jun
# 40      9         2         0   Jun
# 41      5         2         0   Jun
# 42      4         0         0   Jun
# 43      6         1         0   Jun
# 44     25         9         0   Jun

# %%
video_per_month=video_data.groupby('Month',as_index=False).size()

# %%
video_per_month
# Out:
#   Month  size
# 0   Aug     7
# 1   Jul    21
# 2   Jun    17

# %%
sort_order = ['JAN','FEB','MAR','APR','MAY','JUN',
             'JUL','AUG','SEP','OCT','NOV','DEC']

# %%
video_per_month.index=pd.CategoricalIndex(video_per_month['Month'],categories=sort_order,ordered=True)

# %%
video_per_month.sort_index()

# %%
ax2=sns.barplot(x='Month',y='size', data=video_per_month)

# %%
video_data.to_csv('Video_Details(volleyball world).csv')
